# %% [markdown]
# <a href="https://colab.research.google.com/github/Mahmoud4812/Hyperparameter-optimization--freesolv_2/blob/main/Project_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
 # !pip install dragonfly-opt
 # !pip install -U hyperopt
 # !pip install hpbandster ConfigSpace
 # !pip install bayesian-optimization
 # !pip install optuna
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: dragonfly-opt in /usr/local/lib/python3.7/dist-packages (0.1.6)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from dragonfly-opt) (1.15.0)
# Requirement already satisfied: future in /usr/local/lib/python3.7/dist-packages (from dragonfly-opt) (0.16.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from dragonfly-opt) (1.21.6)
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from dragonfly-opt) (1.7.3)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: hyperopt in /usr/local/lib/python3.7/dist-packages (0.2.7)
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from hyperopt) (1.7.3)
# Requirement already satisfied: cloudpickle in /usr/local/lib/python3.7/dist-packages (from hyperopt) (1.3.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from hyperopt) (1.21.6)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from hyperopt) (1.15.0)
# Requirement already satisfied: networkx>=2.2 in /usr/local/lib/python3.7/dist-packages (from hyperopt) (2.6.3)
# Requirement already satisfied: future in /usr/local/lib/python3.7/dist-packages (from hyperopt) (0.16.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from hyperopt) (4.64.0)
# Requirement already satisfied: py4j in /usr/local/lib/python3.7/dist-packages (from hyperopt) (0.10.9.5)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: hpbandster in /usr/local/lib/python3.7/dist-packages (0.7.4)
# Requirement already satisfied: ConfigSpace in /usr/local/lib/python3.7/dist-packages (0.5.0)
# Requirement already satisfied: Pyro4 in /usr/local/lib/python3.7/dist-packages (from hpbandster) (4.82)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from hpbandster) (1.21.6)
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from hpbandster) (1.7.3)
# Requirement already satisfied: netifaces in /usr/local/lib/python3.7/dist-packages (from hpbandster) (0.11.0)
# Requirement already satisfied: serpent in /usr/local/lib/python3.7/dist-packages (from hpbandster) (1.41)
# Requirement already satisfied: statsmodels in /usr/local/lib/python3.7/dist-packages (from hpbandster) (0.10.2)
# Requirement already satisfied: cython in /usr/local/lib/python3.7/dist-packages (from ConfigSpace) (0.29.30)
# Requirement already satisfied: pyparsing in /usr/local/lib/python3.7/dist-packages (from ConfigSpace) (3.0.9)
# Requirement already satisfied: patsy>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from statsmodels->hpbandster) (0.5.2)
# Requirement already satisfied: pandas>=0.19 in /usr/local/lib/python3.7/dist-packages (from statsmodels->hpbandster) (1.3.5)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.19->statsmodels->hpbandster) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.19->statsmodels->hpbandster) (2022.1)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from patsy>=0.4.0->statsmodels->hpbandster) (1.15.0)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: bayesian-optimization in /usr/local/lib/python3.7/dist-packages (1.2.0)
# Requirement already satisfied: scikit-learn>=0.18.0 in /usr/local/lib/python3.7/dist-packages (from bayesian-optimization) (1.0.2)
# Requirement already satisfied: numpy>=1.9.0 in /usr/local/lib/python3.7/dist-packages (from bayesian-optimization) (1.21.6)
# Requirement already satisfied: scipy>=0.14.0 in /usr/local/lib/python3.7/dist-packages (from bayesian-optimization) (1.7.3)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from scikit-learn>=0.18.0->bayesian-optimization) (1.1.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn>=0.18.0->bayesian-optimization) (3.1.0)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: optuna in /usr/local/lib/python3.7/dist-packages (2.10.1)
# Requirement already satisfied: sqlalchemy>=1.1.0 in /usr/local/lib/python3.7/dist-packages (from optuna) (1.4.39)
# Requirement already satisfied: scipy!=1.4.0 in /usr/local/lib/python3.7/dist-packages (from optuna) (1.7.3)
# Requirement already satisfied: cliff in /usr/local/lib/python3.7/dist-packages (from optuna) (3.10.1)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from optuna) (4.64.0)
# Requirement already satisfied: colorlog in /usr/local/lib/python3.7/dist-packages (from optuna) (6.6.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.7/dist-packages (from optuna) (21.3)
# Requirement already satisfied: cmaes>=0.8.2 in /usr/local/lib/python3.7/dist-packages (from optuna) (0.8.2)
# Requirement already satisfied: alembic in /usr/local/lib/python3.7/dist-packages (from optuna) (1.8.1)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.7/dist-packages (from optuna) (3.13)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from optuna) (1.21.6)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=20.0->optuna) (3.0.9)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.7/dist-packages (from sqlalchemy>=1.1.0->optuna) (1.1.2)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from sqlalchemy>=1.1.0->optuna) (4.12.0)
# Requirement already satisfied: importlib-resources in /usr/local/lib/python3.7/dist-packages (from alembic->optuna) (5.8.0)
# Requirement already satisfied: Mako in /usr/local/lib/python3.7/dist-packages (from alembic->optuna) (1.2.1)
# Requirement already satisfied: pbr!=2.1.0,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from cliff->optuna) (5.9.0)
# Requirement already satisfied: autopage>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from cliff->optuna) (0.5.1)
# Requirement already satisfied: cmd2>=1.0.0 in /usr/local/lib/python3.7/dist-packages (from cliff->optuna) (2.4.2)
# Requirement already satisfied: PrettyTable>=0.7.2 in /usr/local/lib/python3.7/dist-packages (from cliff->optuna) (3.3.0)
# Requirement already satisfied: stevedore>=2.0.1 in /usr/local/lib/python3.7/dist-packages (from cliff->optuna) (3.5.0)
# Requirement already satisfied: wcwidth>=0.1.7 in /usr/local/lib/python3.7/dist-packages (from cmd2>=1.0.0->cliff->optuna) (0.2.5)
# Requirement already satisfied: attrs>=16.3.0 in /usr/local/lib/python3.7/dist-packages (from cmd2>=1.0.0->cliff->optuna) (21.4.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from cmd2>=1.0.0->cliff->optuna) (4.1.1)
# Requirement already satisfied: pyperclip>=1.6 in /usr/local/lib/python3.7/dist-packages (from cmd2>=1.0.0->cliff->optuna) (1.8.2)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->sqlalchemy>=1.1.0->optuna) (3.8.1)
# Requirement already satisfied: MarkupSafe>=0.9.2 in /usr/local/lib/python3.7/dist-packages (from Mako->alembic->optuna) (2.0.1)

# %%
import numpy as np
import pandas as pd
import torch
import torch.nn as nn
from torch.utils.data import TensorDataset
from pandas import read_csv
from sklearn.impute import SimpleImputer

# %%
initial_targets=pd.read_csv("freesolv.csv")
initial_features=pd.read_csv("sampl(freesolv)_global_cdf_rdkit.csv")

# %%
initial_targets.head()
# Out:
#                    smiles  freesolv
# 0  CN(C)C(=O)c1ccc(cc1)OC    -11.01
# 1            CS(=O)(=O)Cl     -4.87
# 2                CC(C)C=C      1.83
# 3              CCc1cnccn1     -5.45
# 4                CCCCCCCO     -4.21

# %%
initial_features.head()
# Out:
#    ('RDKit2DNormalized_calculated', <class 'bool'>)  \
# 0                                              True
# 1                                              True
# 2                                              True
# 3                                              True
# 4                                              True
#
#    ('BalabanJ', <class 'numpy.float64'>)  \
# 0                               0.966925
# 1                               0.995398
# 2                               0.964639
# 3                               0.965093
# 4                               0.933046
#
#    ('BertzCT', <class 'numpy.float64'>)  ('Chi0', <class 'numpy.float64'>)  \
# 0                              0.021288                           0.016905
# 1                              0.002369                           0.000173
# 2                              0.000899                           0.000130
# 3                              0.004815                           0.000780
# 4                              0.000933                           0.001176
#
#    ('Chi0n', <class 'numpy.float64'>)  ('Chi0v', <class 'numpy.float64'>)  \
# 0                            0.025143                            0.016710
# 1                            0.000022                            0.000364
# 2                            0.000333                            0.000232
# 3                            0.001336                            0.000853
# 4                            0.003508                            0.002201
#
#    ('Chi1', <class 'numpy.float64'>)  ('Chi1n', <class 'numpy.float64'>)  \
# 0                           0.014067                            0.015455
# 1                           0.000038                            0.000012
# 2                           0.000074                            0.000415
# 3                           0.001327                            0.002205
# 4                           0.001296                            0.008297
#
#    ('Chi1v', <class 'numpy.float64'>)  ('Chi2n', <class 'numpy.float64'>)  \
# 0                            0.009769                            0.019653
# 1                            0.006144                            0.000090
# 2                            0.000585                            0.001226
# 3                            0.001836                            0.001464
# 4                            0.005503                            0.005246
#
#    ...  ('fr_sulfonamd', <class 'numpy.float64'>)  \
# 0  ...                               1.593061e-17
# 1  ...                               1.593061e-17
# 2  ...                               1.593061e-17
# 3  ...                               1.593061e-17
# 4  ...                               1.593061e-17
#
#    ('fr_sulfone', <class 'numpy.float64'>)  \
# 0                             5.766101e-14
# 1                             5.766101e-14
# 2                             5.766101e-14
# 3                             5.766101e-14
# 4                             5.766101e-14
#
#    ('fr_term_acetylene', <class 'numpy.float64'>)  \
# 0                                    2.957989e-11
# 1                                    2.957989e-11
# 2                                    2.957989e-11
# 3                                    2.957989e-11
# 4                                    2.957989e-11
#
#    ('fr_tetrazole', <class 'numpy.float64'>)  \
# 0                                   0.168378
# 1                                   0.168378
# 2                                   0.168378
# 3                                   0.168378
# 4                                   0.168378
#
#    ('fr_thiazole', <class 'numpy.float64'>)  \
# 0                                   0.16738
# 1                                   0.16738
# 2                                   0.16738
# 3                                   0.16738
# 4                                   0.16738
#
#    ('fr_thiocyan', <class 'numpy.float64'>)  \
# 0                              1.481515e-18
# 1                              1.481515e-18
# 2                              1.481515e-18
# 3                              1.481515e-18
# 4                              1.481515e-18
#
#    ('fr_thiophene', <class 'numpy.float64'>)  \
# 0                               2.324150e-16
# 1                               2.324150e-16
# 2                               2.324150e-16
# 3                               2.324150e-16
# 4                               2.324150e-16
#
#    ('fr_unbrch_alkane', <class 'numpy.float64'>)  \
# 0                                   4.703598e-08
# 1                                   4.703598e-08
# 2                                   4.703598e-08
# 3                                   4.703598e-08
# 4                                   9.999840e-01
#
#    ('fr_urea', <class 'numpy.float64'>)  ('qed', <class 'numpy.float64'>)
# 0                              0.166633                          0.649586
# 1                              0.166633                          0.255658
# 2                              0.166633                          0.245444
# 3                              0.166633                          0.409113
# 4                              0.166633                          0.420022
#
# [5 rows x 201 columns]

# %%
del initial_features ["('RDKit2DNormalized_calculated', <class 'bool'>)"]
del initial_targets ["smiles"]

# %%
initial_features.shape
# Out:
# (642, 200)

# %%
initial_targets.shape
# Out:
# (642, 1)

# %%
initial_features.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 642 entries, 0 to 641
# Columns: 200 entries, ('BalabanJ', <class 'numpy.float64'>) to ('qed', <class 'numpy.float64'>)
# dtypes: float64(200)
# memory usage: 1003.2 KB

# %%
initial_features.isnull().sum().sum()
# Out:
# 0

# %%
initial_targets.isnull().sum().sum()
# Out:
# 0

# %%
X=initial_features
Y=initial_targets

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(X,Y, test_size=0.1, random_state=1)

# %%
from sklearn import preprocessing
# scaler_data = preprocessing.MinMaxScaler()
# X_train = scaler_data.fit_transform(X_train)
# X_test = scaler_data.transform(X_test)
scaler_labels = preprocessing.MinMaxScaler()
Y_train = scaler_labels.fit_transform(Y_train.values.reshape(-1, 1))
Y_test = scaler_labels.transform(Y_test.values.reshape(-1, 1))
print(X_train.shape, Y_train.shape, X_test.shape, Y_test.shape)
# Out:
# (577, 200) (577, 1) (65, 200) (65, 1)

# %%
print(X.max().max())
print(X.min().min())
print(Y_train.min().min())
print(Y_test.max().max())
# Out:
# 1.0
# 0.0
# 0.0
# 0.9809688581314879

# %%
X_train=np.array(X_train)
X_test=np.array(X_test)

# %%
device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')

# %%
# transform to torch tensor
tensor_x = torch.tensor(X_train, dtype=torch.float).to(device)
tensor_x2 = torch.tensor(X_test, dtype=torch.float).to(device)
tensor_y = torch.tensor(Y_train, dtype=torch.float).to(device)
tensor_y2 = torch.tensor(Y_test, dtype=torch.float).to(device)

# %%
trainset = TensorDataset(tensor_x, tensor_y)
testset = TensorDataset(tensor_x2,tensor_y2)

# %%
#trainset[0]

# %%
#testset[0]

# %%
# %%capture
try:
    import ray
except:
    # !pip install -U ray
    import ray

# %%
from functools import partial
import numpy as np
import os
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.data import random_split
from torchsummary import summary
from ray import tune
from ray.tune import CLIReporter
from ray.tune.schedulers import ASHAScheduler

# %%
from ray.tune.suggest.hyperopt import HyperOptSearch
from ray.tune.suggest.optuna import OptunaSearch
from ray.tune.suggest.dragonfly import DragonflySearch
from ray.tune.suggest.bayesopt import BayesOptSearch
from ray.tune.schedulers.hb_bohb import HyperBandForBOHB
from ray.tune.schedulers import AsyncHyperBandScheduler
from ray.tune.schedulers import MedianStoppingRule
from ray.tune.schedulers import PopulationBasedTraining
from ray.tune.suggest.bohb import TuneBOHB
from ray.tune.suggest.basic_variant import BasicVariantGenerator
from ray.tune.suggest import ConcurrencyLimiter
# Out:
# /usr/local/lib/python3.7/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
def load_data(data_dir=None):
    return trainset, testset

# %%
class Net(nn.Module):
    def __init__(self, config):
        super().__init__()

        self.config = config
        self.hidden_dim1 = int(self.config.get("hidden_dim1", 100))
        self.hidden_dim2 = int(self.config.get("hidden_dim2", 100))
        self.hidden_dim3 = int(self.config.get("hidden_dim3", 100))

        self.act1 = self.config.get("act1", "relu") 
        self.act2 = self.config.get("act2", "relu") 
        self.act3 = self.config.get("act3", "relu")

        self.linear1 = nn.Linear(200, self.hidden_dim1)
        self.linear2 = nn.Linear(self.hidden_dim1, self.hidden_dim2)
        self.linear3 = nn.Linear(self.hidden_dim2, self.hidden_dim3)
        self.linear4 = nn.Linear(self.hidden_dim3, 1)
    
    @staticmethod
    def activation_func(act_str):
        if act_str=="tanh":
            return eval("torch."+act_str)
        elif act_str=="selu" or act_str=="relu":   
            return eval("torch.nn.functional."+act_str)

    def forward(self, x):
        output = self.linear1(x)
        output = self.activation_func(self.act1)(output)
        output = self.linear2(output)
        output = self.activation_func(self.act2)(output)
        output = self.linear3(output)
        output = self.activation_func(self.act3)(output)
        output = self.linear4(output)        
        return output

# %%
model = Net({})

# %%
def trainable_func(config, checkpoint_dir=None, data_dir=None, epochs=10):

    net = Net(config)

    device = "cpu"
    if torch.cuda.is_available():
        device = "cuda:0"
        if torch.cuda.device_count() > 1:
            net = nn.DataParallel(net)
    net.to(device)

    '''
    Define a loss function
    '''
  

    ## Regression
    criterion = nn.MSELoss(reduction='sum')

    # Define an optimizer 
    optimizer = optim.Adam(net.parameters(), lr=config.get("lr",0.0003))

    if checkpoint_dir:
        model_state, optimizer_state = torch.load(
            os.path.join(checkpoint_dir, "checkpoint"))
        net.load_state_dict(model_state)
        optimizer.load_state_dict(optimizer_state)

    # Load data
    trainset, testset = load_data(data_dir)

    # Split the dataset into training and validation sets
    train_size = int(len(trainset) * 0.8)
    train_subset, val_subset = random_split(trainset, [train_size, len(trainset) - train_size])
    
    # Define data loaders (which combines a dataset and a sampler, and provides an iterable over the given dataset)
    trainloader = torch.utils.data.DataLoader(
        train_subset,
        batch_size=int(config.get("batch_size",32)),
        shuffle=True,
        num_workers=2)
    valloader = torch.utils.data.DataLoader(
        val_subset,
        batch_size=int(config.get("batch_size",32)),
        shuffle=True,
        num_workers=2)

    for epoch in range(epochs):  # loop over the dataset multiple times
        epoch_train_loss = 0.0
        # epoch_steps = 0
        net.train() # Prepare model for training
        for i, data in enumerate(trainloader):
            # get the inputs; data is a list of [inputs, labels]
            inputs, labels = data
            inputs, labels = inputs.to(device), labels.to(device)

            # zero the parameter gradients
            optimizer.zero_grad()

            # forward + backward + optimize
            outputs = net(inputs)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()

            '''
            Compute train loss without scaling to print
            ''' 
            # outputs = torch.tensor(scaler_labels.inverse_transform(outputs.detach().cpu())).to(device)    
            # labels = torch.tensor(scaler_labels.inverse_transform(labels.cpu())).to(device)  
            # loss_train = criterion(outputs, labels) 
            # epoch_train_loss += loss_train.detach().item()
        # print("[%d] loss: %.3f" % (epoch + 1, epoch_train_loss / len(train_subset)))

        # Validation loss
        val_loss = 0.0
        net.eval() # Prepare model for evaluation
        for i, data in enumerate(valloader):
            with torch.no_grad():
                inputs, labels = data
                inputs, labels = inputs.to(device), labels.to(device)

                outputs = net(inputs)

                # Inverse transform of the labels' scaler
                outputs = torch.tensor(scaler_labels.inverse_transform(outputs.detach().cpu())).to(device)    
                labels = torch.tensor(scaler_labels.inverse_transform(labels.cpu())).to(device) 

                loss = criterion(outputs, labels)
                #print(loss)
                val_loss += loss.cpu().numpy()

        with tune.checkpoint_dir(epoch) as checkpoint_dir:
            path = os.path.join(checkpoint_dir, "checkpoint")
            torch.save((net.state_dict(), optimizer.state_dict()), path)

        tune.report(epoch = epoch, loss=(val_loss / len(val_subset)))
    print("Finished Training")

# %%
def test_score(config, net, device="cpu"):
    trainset, testset = load_data()

    testloader = torch.utils.data.DataLoader(
        testset, batch_size=int(config.get("batch_size",32)), shuffle=False, num_workers=2)
    
    ## Regression
    criterion = nn.MSELoss(reduction='sum')

    # Test loss
    test_loss = 0.0
    net.eval() # Prepare model for evaluation
    for i, data in enumerate(testloader):
        with torch.no_grad():
            inputs, labels = data
            inputs, labels = inputs.to(device), labels.to(device)

            outputs = net(inputs)

            # Inverse transform of the labels' scaler
            outputs = torch.tensor(scaler_labels.inverse_transform(outputs.detach().cpu())).to(device)    
            labels = torch.tensor(scaler_labels.inverse_transform(labels.cpu())).to(device) 

            loss = criterion(outputs, labels)
            test_loss += loss.cpu().numpy()

    return test_loss / len(testset)

# %%
ray.init() # Here we use ray.init() to evaluate available_resources for Ray
print(ray.available_resources())
ray.shutdown()  # Restart Ray defensively in case the ray connection is lost. 

# Start Ray runtime with specific resources (not nessesarily all resources)
# You can change this values based on your machine resources)
ray.init(num_cpus=2, num_gpus=0) 

"""Check Ray Tune is working properly (for trainable class)"""
# from ray.tune.utils import validate_save_restore
# validate_save_restore(Trainable)
# validate_save_restore(Trainable, use_object_store=True)
# print("Success!")
""""""
# Out:
# {'node:172.28.0.2': 1.0, 'CPU': 2.0, 'object_store_memory': 3949722009.0, 'memory': 7899444020.0}
# ''

# %%
# %%capture
try:
    import optuna
except:
    # %pip install optuna
    import optuna

# %%
extracted_col = Y["freesolv"]
#print("column to added from first dataframe to second:")
#display(extracted_col)
  
data = X.join(extracted_col)
print("Second dataframe after adding column from first dataframe:")
display(data)
# Out:
# Second dataframe after adding column from first dataframe:
#      ('BalabanJ', <class 'numpy.float64'>)  \
# 0                                 0.966925
# 1                                 0.995398
# 2                                 0.964639
# 3                                 0.965093
# 4                                 0.933046
# ..                                     ...
# 637                               0.972665
# 638                               0.800607
# 639                               0.975400
# 640                               0.933046
# 641                               0.752965
#
#      ('BertzCT', <class 'numpy.float64'>)  ('Chi0', <class 'numpy.float64'>)  \
# 0                                0.021288                           0.016905
# 1                                0.002369                           0.000173
# 2                                0.000899                           0.000130
# 3                                0.004815                           0.000780
# 4                                0.000933                           0.001176
# ..                                    ...                                ...
# 637                              0.002603                           0.007318
# 638                              0.000743                           0.000042
# 639                              0.008812                           0.001766
# 640                              0.000933                           0.001176
# 641                              0.000816                           0.000123
#
#      ('Chi0n', <class 'numpy.float64'>)  ('Chi0v', <class 'numpy.float64'>)  \
# 0                              0.025143                            0.016710
# 1                              0.000022                            0.000364
# 2                              0.000333                            0.000232
# 3                              0.001336                            0.000853
# 4                              0.003508                            0.002201
# ..                                  ...                                 ...
# 637                            0.017536                            0.011438
# 638                            0.000126                            0.000098
# 639                            0.001191                            0.000763
# 640                            0.003266                            0.004267
# 641                            0.000229                            0.000166
#
#      ('Chi1', <class 'numpy.float64'>)  ('Chi1n', <class 'numpy.float64'>)  \
# 0                             0.014067                            0.015455
# 1                             0.000038                            0.000012
# 2                             0.000074                            0.000415
# 3                             0.001327                            0.002205
# 4                             0.001296                            0.008297
# ..                                 ...                                 ...
# 637                           0.006481                            0.023713
# 638                           0.000123                            0.000862
# 639                           0.002197                            0.001795
# 640                           0.001296                            0.007752
# 641                           0.000319                            0.000767
#
#      ('Chi1v', <class 'numpy.float64'>)  ('Chi2n', <class 'numpy.float64'>)  \
# 0                              0.009769                            0.019653
# 1                              0.006144                            0.000090
# 2                              0.000585                            0.001226
# 3                              0.001836                            0.001464
# 4                              0.005503                            0.005246
# ..                                  ...                                 ...
# 637                            0.014803                            0.014817
# 638                            0.000934                            0.001156
# 639                            0.001572                            0.002137
# 640                            0.009802                            0.004906
# 641                            0.000864                            0.000610
#
#      ('Chi2v', <class 'numpy.float64'>)  ...  \
# 0                              0.010130  ...
# 1                              0.031133  ...
# 2                              0.000503  ...
# 3                              0.000610  ...
# 4                              0.002431  ...
# ..                                  ...  ...
# 637                            0.007464  ...
# 638                            0.000472  ...
# 639                            0.000920  ...
# 640                            0.004742  ...
# 641                            0.000235  ...
#
#      ('fr_sulfone', <class 'numpy.float64'>)  \
# 0                               5.766101e-14
# 1                               5.766101e-14
# 2                               5.766101e-14
# 3                               5.766101e-14
# 4                               5.766101e-14
# ..                                       ...
# 637                             5.766101e-14
# 638                             5.766101e-14
# 639                             5.766101e-14
# 640                             5.766101e-14
# 641                             5.766101e-14
#
#      ('fr_term_acetylene', <class 'numpy.float64'>)  \
# 0                                      2.957989e-11
# 1                                      2.957989e-11
# 2                                      2.957989e-11
# 3                                      2.957989e-11
# 4                                      2.957989e-11
# ..                                              ...
# 637                                    2.957989e-11
# 638                                    2.957989e-11
# 639                                    2.957989e-11
# 640                                    2.957989e-11
# 641                                    2.957989e-11
#
#      ('fr_tetrazole', <class 'numpy.float64'>)  \
# 0                                     0.168378
# 1                                     0.168378
# 2                                     0.168378
# 3                                     0.168378
# 4                                     0.168378
# ..                                         ...
# 637                                   0.168378
# 638                                   0.168378
# 639                                   0.168378
# 640                                   0.168378
# 641                                   0.168378
#
#      ('fr_thiazole', <class 'numpy.float64'>)  \
# 0                                     0.16738
# 1                                     0.16738
# 2                                     0.16738
# 3                                     0.16738
# 4                                     0.16738
# ..                                        ...
# 637                                   0.16738
# 638                                   0.16738
# 639                                   0.16738
# 640                                   0.16738
# 641                                   0.16738
#
#      ('fr_thiocyan', <class 'numpy.float64'>)  \
# 0                                1.481515e-18
# 1                                1.481515e-18
# 2                                1.481515e-18
# 3                                1.481515e-18
# 4                                1.481515e-18
# ..                                        ...
# 637                              1.481515e-18
# 638                              1.481515e-18
# 639                              1.481515e-18
# 640                              1.481515e-18
# 641                              1.481515e-18
#
#      ('fr_thiophene', <class 'numpy.float64'>)  \
# 0                                 2.324150e-16
# 1                                 2.324150e-16
# 2                                 2.324150e-16
# 3                                 2.324150e-16
# 4                                 2.324150e-16
# ..                                         ...
# 637                               2.324150e-16
# 638                               2.324150e-16
# 639                               2.324150e-16
# 640                               2.324150e-16
# 641                               2.324150e-16
#
#      ('fr_unbrch_alkane', <class 'numpy.float64'>)  \
# 0                                     4.703598e-08
# 1                                     4.703598e-08
# 2                                     4.703598e-08
# 3                                     4.703598e-08
# 4                                     9.999840e-01
# ..                                             ...
# 637                                   9.999840e-01
# 638                                   4.703598e-08
# 639                                   4.703598e-08
# 640                                   9.999840e-01
# 641                                   4.703598e-08
#
#      ('fr_urea', <class 'numpy.float64'>)  ('qed', <class 'numpy.float64'>)  \
# 0                                0.166633                          0.649586
# 1                                0.166633                          0.255658
# 2                                0.166633                          0.245444
# 3                                0.166633                          0.409113
# 4                                0.166633                          0.420022
# ..                                    ...                               ...
# 637                              0.166633                          0.276067
# 638                              0.166633                          0.271752
# 639                              0.166633                          0.456147
# 640                              0.166633                          0.231180
# 641                              0.166633                          0.248962
#
#      freesolv
# 0      -11.01
# 1       -4.87
# 2        1.83
# 3       -5.45
# 4       -4.21
# ..        ...
# 637     -2.04
# 638     -5.48
# 639     -8.83
# 640      0.29
# 641     -5.06
#
# [642 rows x 201 columns]

# %%
# !pip install optuna
import optuna
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: optuna in /usr/local/lib/python3.7/dist-packages (2.10.1)
# Requirement already satisfied: scipy!=1.4.0 in /usr/local/lib/python3.7/dist-packages (from optuna) (1.7.3)
# Requirement already satisfied: cliff in /usr/local/lib/python3.7/dist-packages (from optuna) (3.10.1)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.7/dist-packages (from optuna) (21.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from optuna) (4.64.0)
# Requirement already satisfied: alembic in /usr/local/lib/python3.7/dist-packages (from optuna) (1.8.1)
# Requirement already satisfied: cmaes>=0.8.2 in /usr/local/lib/python3.7/dist-packages (from optuna) (0.8.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from optuna) (1.21.6)
# Requirement already satisfied: colorlog in /usr/local/lib/python3.7/dist-packages (from optuna) (6.6.0)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.7/dist-packages (from optuna) (3.13)
# Requirement already satisfied: sqlalchemy>=1.1.0 in /usr/local/lib/python3.7/dist-packages (from optuna) (1.4.39)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=20.0->optuna) (3.0.9)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.7/dist-packages (from sqlalchemy>=1.1.0->optuna) (1.1.2)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from sqlalchemy>=1.1.0->optuna) (4.12.0)
# Requirement already satisfied: Mako in /usr/local/lib/python3.7/dist-packages (from alembic->optuna) (1.2.1)
# Requirement already satisfied: importlib-resources in /usr/local/lib/python3.7/dist-packages (from alembic->optuna) (5.8.0)
# Requirement already satisfied: autopage>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from cliff->optuna) (0.5.1)
# Requirement already satisfied: cmd2>=1.0.0 in /usr/local/lib/python3.7/dist-packages (from cliff->optuna) (2.4.2)
# Requirement already satisfied: stevedore>=2.0.1 in /usr/local/lib/python3.7/dist-packages (from cliff->optuna) (3.5.0)
# Requirement already satisfied: PrettyTable>=0.7.2 in /usr/local/lib/python3.7/dist-packages (from cliff->optuna) (3.3.0)
# Requirement already satisfied: pbr!=2.1.0,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from cliff->optuna) (5.9.0)
# Requirement already satisfied: pyperclip>=1.6 in /usr/local/lib/python3.7/dist-packages (from cmd2>=1.0.0->cliff->optuna) (1.8.2)
# Requirement already satisfied: attrs>=16.3.0 in /usr/local/lib/python3.7/dist-packages (from cmd2>=1.0.0->cliff->optuna) (21.4.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from cmd2>=1.0.0->cliff->optuna) (4.1.1)
# Requirement already satisfied: wcwidth>=0.1.7 in /usr/local/lib/python3.7/dist-packages (from cmd2>=1.0.0->cliff->optuna) (0.2.5)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->sqlalchemy>=1.1.0->optuna) (3.8.1)
# Requirement already satisfied: MarkupSafe>=0.9.2 in /usr/local/lib/python3.7/dist-packages (from Mako->alembic->optuna) (2.0.1)

# %%
 config = {
        "act1 ": tune.choice(["relu","tanh","selu"]),
        "act2" : tune.choice(["relu","tanh","selu"]),
        "act3" : tune.choice(["relu","tanh","selu"]),
        "lr": tune.quniform(0.0005, 0.001, 0.0001),
        "batch_size": tune.choice([8, 16, 32]),
        "hidden_dim1" : tune.quniform(50, 200, 10),
        "hidden_dim2" : tune.quniform(50, 200, 10),
        "hidden_dim3" : tune.quniform(50, 200, 10),
    }

# %%
def main(num_samples=10, max_num_epochs=10, gpus_per_trial=2):

    # define data directory here if you want to load data from files
    data_dir = os.path.abspath("./data")
    load_data(data_dir)

    # define the search space of hyperparameters
    config = {
        "act1 ": tune.choice(["relu","tanh","selu"]),
        "act2" : tune.choice(["relu","tanh","selu"]),
        "act3" : tune.choice(["relu","tanh","selu"]),
        "lr": tune.quniform(0.0005, 0.001, 0.0001),
        "batch_size": tune.choice([8, 16, 32]),
        "hidden_dim1" : tune.quniform(50, 200, 10),
        "hidden_dim2" : tune.quniform(50, 200, 10),
        "hidden_dim3" : tune.quniform(50, 200, 10),
    }

    # Optuna search algorithm
    from ray.tune.suggest.optuna import OptunaSearch 
    from ray.tune.suggest import ConcurrencyLimiter
    search_alg = OptunaSearch(
        metric="loss", #or accuracy, etc.
        mode="min" #or max
        # seed = 42,
        # points_to_evaluate=[
        # {'lr': 0.0005, 'hidden_size': 150.0, 'readout1_out': 200.0, 'readout2_out': 180.0}
        # ],
        )
    search_alg = ConcurrencyLimiter(search_alg, max_concurrent=10)

    scheduler = ASHAScheduler(
        metric ="loss",
        mode="min",
        max_t=max_num_epochs,
        reduction_factor=2, 
        grace_period=4,
        brackets=5
        )
    
    reporter = CLIReporter(
        # parameter_columns=["l1", "l2", "lr", "batch_size"],
        metric_columns=["loss", "training_iteration"]
        )
    
    # wrap data loading and training for tuning using `partial` 
    # (note that there exist other methods for this purpose)
    result = tune.run(
        partial(trainable_func, data_dir=data_dir,epochs=max_num_epochs),
        scheduler=scheduler,
        search_alg=search_alg,
        num_samples=num_samples,
        config=config,
        verbose=3,
        checkpoint_score_attr="loss",
        checkpoint_freq=0,
        keep_checkpoints_num=1,
        # checkpoint_at_end=True,
        # reuse_actors=reuse_actors_status,
        progress_reporter=reporter,
        resources_per_trial={"cpu": 0.5, "gpu": gpus_per_trial},
        stop={"training_iteration": max_num_epochs},                
        )

    best_trial = result.get_best_trial("loss", "min", "last")
    print("Best trial config: {}".format(best_trial.config))
    print("Best trial final validation score: {}".format(
        best_trial.last_result["loss"]))

    best_trained_model = Net(best_trial.config)
    device = "cpu"
    if torch.cuda.is_available():
        device = "cuda:0"
        if gpus_per_trial > 1:
            best_trained_model = nn.DataParallel(best_trained_model)
    best_trained_model.to(device)

    best_checkpoint_dir = best_trial.checkpoint.value
    model_state, optimizer_state = torch.load(os.path.join(
        best_checkpoint_dir, "checkpoint"))
    best_trained_model.load_state_dict(model_state)

    test_score_value = test_score(best_trial.config, best_trained_model, device)
    print("Best trial test set score: {}".format(test_score_value))


if __name__ == "__main__":
    # You can change the number of GPUs per trial here:
    main(num_samples=10, max_num_epochs=12, gpus_per_trial=0)
# Out:
# [I 2022-07-27 08:46:04,373] A new study created in memory with name: optuna
# 2022-07-27 08:46:04,393	INFO logger.py:630 -- pip install "ray[tune]" to see TensorBoard files.
# 2022-07-27 08:46:04,397	WARNING callback.py:106 -- The TensorboardX logger cannot be instantiated because either TensorboardX or one of it's dependencies is not installed. Please make sure you have the latest version of TensorboardX installed: `pip install -U tensorboardx`
# == Status ==
# Current time: 2022-07-27 08:46:04 (running for 00:00:00.45)
# Memory usage on this node: 1.6/12.7 GiB
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 8.000: None | Iter 4.000: None
# Bracket: Iter 8.000: None
# Bracket:
# Bracket:
# Bracket:
# Resources requested: 0.5/2 CPUs, 0/0 GPUs, 0.0/7.36 GiB heap, 0.0/3.68 GiB objects
# Result logdir: /root/ray_results/trainable_func_2022-07-27_08-46-04
# Number of trials: 1/10 (1 RUNNING)
# +-------------------------+----------+------------------+---------+--------+--------+--------------+---------------+---------------+---------------+--------+
# | Trial name              | status   | loc              | act1    | act2   | act3   |   batch_size |   hidden_dim1 |   hidden_dim2 |   hidden_dim3 |     lr |
# |-------------------------+----------+------------------+---------+--------+--------+--------------+---------------+---------------+---------------+--------|
# | trainable_func_8ca59aa4 | RUNNING  | 172.28.0.2:31125 | relu    | selu   | tanh   |           16 |            50 |            50 |           180 | 0.0006 |
# +-------------------------+----------+------------------+---------+--------+--------+--------------+---------------+---------------+---------------+--------+
#
#
# Result for trainable_func_8ca59aa4:
#   date: 2022-07-27_08-46-09
#   done: false
#   epoch: 0
#   experiment_id: c46bbe75ad6e48d8a005acfd916fbc35
#   hostname: f5eee09c4874
#   iterations_since_restore: 1
#   loss: 18.901505068089396
#   node_ip: 172.28.0.2
#   pid: 31125
#   should_checkpoint: true
#   time_since_restore: 0.5093903541564941
#   time_this_iter_s: 0.5093903541564941
#   time_total_s: 0.5093903541564941
#   timestamp: 1658911569
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: 8ca59aa4
#   warmup_time: 0.0051500797271728516
#
# == Status ==
# Current time: 2022-07-27 08:46:10 (running for 00:00:05.79)
# Memory usage on this node: 1.5/12.7 GiB
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 8.000: None | Iter 4.000: None
# Bracket: Iter 8.000: None
# Bracket:
# Bracket:
# Bracket:
# Resources requested: 2.0/2 CPUs, 0/0 GPUs, 0.0/7.36 GiB heap, 0.0/3.68 GiB objects
# Result logdir: /root/ray_results/trainable_func_2022-07-27_08-46-04
# Number of trials: 5/10 (1 PENDING, 4 RUNNING)
# +-------------------------+----------+------------------+---------+--------+--------+--------------+---------------+---------------+---------------+--------+--------+----------------------+
# | Trial name              | status   | loc              | act1    | act2   | act3   |   batch_size |   hidden_dim1 |   hidden_dim2 |   hidden_dim3 |     lr |   loss |   training_iteration |
# |-------------------------+----------+------------------+---------+--------+--------+--------------+---------------+---------------+---------------+--------+--------+----------------------|
# | trainable_func_8ca59aa4 | RUNNING  | 172.28.0.2:31125 | relu    | selu   | tanh   |           16 |            50 |            50 |           180 | 0.0006 | 3.0749 |                    3 |
# | trainable_func_8f252006 | RUNNING  | 172.28.0.2:31172 | tanh    | selu   | selu   |           32 |           120 |           140 |           180 | 0.0008 |        |                      |
# | trainable_func_8f2acb96 | RUNNING  | 172.28.0.2:31180 | relu    | tanh   | tanh   |           32 |           130 |           190 |           180 | 0.0005 |        |                      |
# | trainable_func_8f3539fa | RUNNING  | 172.28.0.2:31280 | relu    | tanh   | selu   |           32 |           180 |           170 |            80 | 0.001  |        |                      |
# | trainable_func_8f3f3e50 | PENDING  |                  | relu    | selu   | selu   |           16 |           180 |           120 |           150 | 0.0006 |        |                      |
# +-------------------------+----------+------------------+---------+--------+--------+--------------+---------------+---------------+---------------+--------+--------+----------------------+
#
#
# == Status ==
# Current time: 2022-07-27 08:46:20 (running for 00:00:16.33)
# Memory usage on this node: 2.0/12.7 GiB
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 8.000: None | Iter 4.000: None
# Bracket: Iter 8.000: None
# Bracket:
# Bracket:
# Bracket:
# Resources requested: 2.0/2 CPUs, 0/0 GPUs, 0.0/7.36 GiB heap, 0.0/3.68 GiB objects
# Result logdir: /root/ray_results/trainable_func_2022-07-27_08-46-04
# Number of trials: 5/10 (1 PENDING, 4 RUNNING)
# +-------------------------+----------+------------------+---------+--------+--------+--------------+---------------+---------------+---------------+--------+--------+----------------------+
# | Trial name              | status   | loc              | act1    | act2   | act3   |   batch_size |   hidden_dim1 |   hidden_dim2 |   hidden_dim3 |     lr |   loss |   training_iteration |
# |-------------------------+----------+------------------+---------+--------+--------+--------------+---------------+---------------+---------------+--------+--------+----------------------|
# | trainable_func_8ca59aa4 | RUNNING  | 172.28.0.2:31125 | relu    | selu   | tanh   |           16 |            50 |            50 |           180 | 0.0006 | 3.0749 |                    3 |
# | trainable_func_8f252006 | RUNNING  | 172.28.0.2:31172 | tanh    | selu   | selu   |           32 |           120 |           140 |           180 | 0.0008 |        |                      |
# | trainable_func_8f2acb96 | RUNNING  | 172.28.0.2:31180 | relu    | tanh   | tanh   |           32 |           130 |           190 |           180 | 0.0005 |        |                      |
# | trainable_func_8f3539fa | RUNNING  | 172.28.0.2:31280 | relu    | tanh   | selu   |           32 |           180 |           170 |            80 | 0.001  |        |                      |
# | trainable_func_8f3f3e50 | PENDING  |                  | relu    | selu   | selu   |           16 |           180 |           120 |           150 | 0.0006 |        |                      |
# +-------------------------+----------+------------------+---------+--------+--------+--------------+---------------+---------------+---------------+--------+--------+----------------------+
#
#
# Result for trainable_func_8f2acb96:
#   date: 2022-07-27_08-46-18
#   done: false
#   epoch: 0
#   experiment_id: 9851dc6b293d48f4936769b227e8e01c
#   hostname: f5eee09c4874
#   iterations_since_restore: 1
#   loss: 46.02020109551706
#   node_ip: 172.28.0.2
#   pid: 31180
#   should_checkpoint: true
#   time_since_restore: 0.5943779945373535
#   time_this_iter_s: 0.5943779945373535
#   time_total_s: 0.5943779945373535
#   timestamp: 1658911578
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: 8f2acb96
#   warmup_time: 0.01262521743774414
#
# Result for trainable_func_8f252006:
#   date: 2022-07-27_08-46-18
#   done: false
#   epoch: 0
#   experiment_id: c88e6a21a2f049109768804a8199d57f
#   hostname: f5eee09c4874
#   iterations_since_restore: 1
#   loss: 41.3705902074427
#   node_ip: 172.28.0.2
#   pid: 31172
#   should_checkpoint: true
#   time_since_restore: 0.5735108852386475
#   time_this_iter_s: 0.5735108852386475
#   time_total_s: 0.5735108852386475
#   timestamp: 1658911578
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: 8f252006
#   warmup_time: 0.005120754241943359
#
# Result for trainable_func_8f3539fa:
#   date: 2022-07-27_08-46-21
#   done: false
#   epoch: 0
#   experiment_id: a1a929bb1f0e4ac0baf539434a720b93
#   hostname: f5eee09c4874
#   iterations_since_restore: 1
#   loss: 17.91164201488788
#   node_ip: 172.28.0.2
#   pid: 31280
#   should_checkpoint: true
#   time_since_restore: 0.7994222640991211
#   time_this_iter_s: 0.7994222640991211
#   time_total_s: 0.7994222640991211
#   timestamp: 1658911581
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: 8f3539fa
#   warmup_time: 0.015590429306030273
#
# Result for trainable_func_8ca59aa4:
#   date: 2022-07-27_08-46-21
#   done: false
#   epoch: 3
#   experiment_id: c46bbe75ad6e48d8a005acfd916fbc35
#   hostname: f5eee09c4874
#   iterations_since_restore: 4
#   loss: 2.232361104760142
#   node_ip: 172.28.0.2
#   pid: 31125
#   should_checkpoint: true
#   time_since_restore: 12.925502300262451
#   time_this_iter_s: 11.396270990371704
#   time_total_s: 12.925502300262451
#   timestamp: 1658911581
#   timesteps_since_restore: 0
#   training_iteration: 4
#   trial_id: 8ca59aa4
#   warmup_time: 0.0051500797271728516
#
# Result for trainable_func_8f2acb96:
#   date: 2022-07-27_08-46-23
#   done: true
#   epoch: 3
#   experiment_id: 9851dc6b293d48f4936769b227e8e01c
#   hostname: f5eee09c4874
#   iterations_since_restore: 4
#   loss: 5.700663133307954
#   node_ip: 172.28.0.2
#   pid: 31180
#   should_checkpoint: true
#   time_since_restore: 5.033273458480835
#   time_this_iter_s: 0.8294694423675537
#   time_total_s: 5.033273458480835
#   timestamp: 1658911583
#   timesteps_since_restore: 0
#   training_iteration: 4
#   trial_id: 8f2acb96
#   warmup_time: 0.01262521743774414
#
# Result for trainable_func_8f3f3e50:
#   date: 2022-07-27_08-46-24
#   done: false
#   epoch: 0
#   experiment_id: 9851dc6b293d48f4936769b227e8e01c
#   hostname: f5eee09c4874
#   iterations_since_restore: 1
#   loss: 15.926675678343937
#   node_ip: 172.28.0.2
#   pid: 31180
#   should_checkpoint: true
#   time_since_restore: 1.1613290309906006
#   time_this_iter_s: 1.1613290309906006
#   time_total_s: 1.1613290309906006
#   timestamp: 1658911584
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: 8f3f3e50
#   warmup_time: 0.01262521743774414
#
# == Status ==
# Current time: 2022-07-27 08:46:25 (running for 00:00:21.34)
# Memory usage on this node: 2.1/12.7 GiB
# Using AsyncHyperBand: num_stopped=1
# Bracket: Iter 8.000: -1.5406402985244922 | Iter 4.000: -3.470584311148012
# Bracket: Iter 8.000: None
# Bracket:
# Bracket:
# Bracket:
# Resources requested: 2.0/2 CPUs, 0/0 GPUs, 0.0/7.36 GiB heap, 0.0/3.68 GiB objects
# Result logdir: /root/ray_results/trainable_func_2022-07-27_08-46-04
# Number of trials: 6/10 (1 PENDING, 4 RUNNING, 1 TERMINATED)
# +-------------------------+------------+------------------+---------+--------+--------+--------------+---------------+---------------+---------------+--------+---------+----------------------+
# | Trial name              | status     | loc              | act1    | act2   | act3   |   batch_size |   hidden_dim1 |   hidden_dim2 |   hidden_dim3 |     lr |    loss |   training_iteration |
# |-------------------------+------------+------------------+---------+--------+--------+--------------+---------------+---------------+---------------+--------+---------+----------------------|
# | trainable_func_8ca59aa4 | RUNNING    | 172.28.0.2:31125 | relu    | selu   | tanh   |           16 |            50 |            50 |           180 | 0.0006 | 1.54064 |                    8 |
# | trainable_func_8f252006 | RUNNING    | 172.28.0.2:31172 | tanh    | selu   | selu   |           32 |           120 |           140 |           180 | 0.0008 | 1.86598 |                    6 |
# | trainable_func_8f3539fa | RUNNING    | 172.28.0.2:31280 | relu    | tanh   | selu   |           32 |           180 |           170 |            80 | 0.001  | 2.42316 |                    5 |
# | trainable_func_8f3f3e50 | RUNNING    | 172.28.0.2:31180 | relu    | selu   | selu   |           16 |           180 |           120 |           150 | 0.0006 | 6.51733 |                    2 |
# | trainable_func_97d7cd20 | PENDING    |                  | selu    | tanh   | relu   |           16 |            90 |           170 |            90 | 0.0008 |         |                      |
# | trainable_func_8f2acb96 | TERMINATED | 172.28.0.2:31180 | relu    | tanh   | tanh   |           32 |           130 |           190 |           180 | 0.0005 | 5.70066 |                    4 |
# +-------------------------+------------+------------------+---------+--------+--------+--------------+---------------+---------------+---------------+--------+---------+----------------------+
#
#
# Result for trainable_func_8f252006:
#   date: 2022-07-27_08-46-25
#   done: false
#   epoch: 6
#   experiment_id: c88e6a21a2f049109768804a8199d57f
#   hostname: f5eee09c4874
#   iterations_since_restore: 7
#   loss: 1.562759511091897
#   node_ip: 172.28.0.2
#   pid: 31172
#   should_checkpoint: true
#   time_since_restore: 7.903144359588623
#   time_this_iter_s: 0.9279658794403076
#   time_total_s: 7.903144359588623
#   timestamp: 1658911585
#   timesteps_since_restore: 0
#   training_iteration: 7
#   trial_id: 8f252006
#   warmup_time: 0.005120754241943359
#
# Result for trainable_func_8f3539fa:
#   date: 2022-07-27_08-46-26
#   done: false
#   epoch: 6
#   experiment_id: a1a929bb1f0e4ac0baf539434a720b93
#   hostname: f5eee09c4874
#   iterations_since_restore: 7
#   loss: 2.180869840029078
#   node_ip: 172.28.0.2
#   pid: 31280
#   should_checkpoint: true
#   time_since_restore: 5.898809194564819
#   time_this_iter_s: 0.8196029663085938
#   time_total_s: 5.898809194564819
#   timestamp: 1658911586
#   timesteps_since_restore: 0
#   training_iteration: 7
#   trial_id: 8f3539fa
#   warmup_time: 0.015590429306030273
#
# Result for trainable_func_8ca59aa4:
#   date: 2022-07-27_08-46-26
#   done: false
#   epoch: 8
#   experiment_id: c46bbe75ad6e48d8a005acfd916fbc35
#   hostname: f5eee09c4874
#   iterations_since_restore: 9
#   loss: 1.573911480394501
#   node_ip: 172.28.0.2
#   pid: 31125
#   should_checkpoint: true
#   time_since_restore: 18.14114212989807
#   time_this_iter_s: 1.0683069229125977
#   time_total_s: 18.14114212989807
#   timestamp: 1658911586
#   timesteps_since_restore: 0
#   training_iteration: 9
#   trial_id: 8ca59aa4
#   warmup_time: 0.0051500797271728516
#
# Result for trainable_func_8f3f3e50:
#   date: 2022-07-27_08-46-29
#   done: false
#   epoch: 4
#   experiment_id: 9851dc6b293d48f4936769b227e8e01c
#   hostname: f5eee09c4874
#   iterations_since_restore: 5
#   loss: 2.654887695531256
#   node_ip: 172.28.0.2
#   pid: 31180
#   should_checkpoint: true
#   time_since_restore: 6.332616806030273
#   time_this_iter_s: 1.2321534156799316
#   time_total_s: 6.332616806030273
#   timestamp: 1658911589
#   timesteps_since_restore: 0
#   training_iteration: 5
#   trial_id: 8f3f3e50
#   warmup_time: 0.01262521743774414
#
# Result for trainable_func_8f252006:
#   date: 2022-07-27_08-46-30
#   done: true
#   epoch: 11
#   experiment_id: c88e6a21a2f049109768804a8199d57f
#   hostname: f5eee09c4874
#   iterations_since_restore: 12
#   loss: 1.0716665870671747
#   node_ip: 172.28.0.2
#   pid: 31172
#   should_checkpoint: true
#   time_since_restore: 12.02990436553955
#   time_this_iter_s: 0.7557008266448975
#   time_total_s: 12.02990436553955
#   timestamp: 1658911590
#   timesteps_since_restore: 0
#   training_iteration: 12
#   trial_id: 8f252006
#   warmup_time: 0.005120754241943359
#
# Result for trainable_func_8ca59aa4:
#   date: 2022-07-27_08-46-30
#   done: true
#   epoch: 11
#   experiment_id: c46bbe75ad6e48d8a005acfd916fbc35
#   hostname: f5eee09c4874
#   iterations_since_restore: 12
#   loss: 1.8908101863835665
#   node_ip: 172.28.0.2
#   pid: 31125
#   should_checkpoint: true
#   time_since_restore: 21.519395112991333
#   time_this_iter_s: 1.0552117824554443
#   time_total_s: 21.519395112991333
#   timestamp: 1658911590
#   timesteps_since_restore: 0
#   training_iteration: 12
#   trial_id: 8ca59aa4
#   warmup_time: 0.0051500797271728516
#
# Result for trainable_func_8f3539fa:
#   date: 2022-07-27_08-46-30
#   done: true
#   epoch: 11
#   experiment_id: a1a929bb1f0e4ac0baf539434a720b93
#   hostname: f5eee09c4874
#   iterations_since_restore: 12
#   loss: 1.3442792482690165
#   node_ip: 172.28.0.2
#   pid: 31280
#   should_checkpoint: true
#   time_since_restore: 9.997159242630005
#   time_this_iter_s: 0.7583014965057373
#   time_total_s: 9.997159242630005
#   timestamp: 1658911590
#   timesteps_since_restore: 0
#   training_iteration: 12
#   trial_id: 8f3539fa
#   warmup_time: 0.015590429306030273
#
# == Status ==
# Current time: 2022-07-27 08:46:31 (running for 00:00:26.61)
# Memory usage on this node: 2.1/12.7 GiB
# Using AsyncHyperBand: num_stopped=1
# Bracket: Iter 8.000: -1.3988540027902818 | Iter 4.000: -3.470584311148012
# Bracket: Iter 8.000: -1.5925466739714083
# Bracket:
# Bracket:
# Bracket:
# Resources requested: 2.0/2 CPUs, 0/0 GPUs, 0.0/7.36 GiB heap, 0.0/3.68 GiB objects
# Result logdir: /root/ray_results/trainable_func_2022-07-27_08-46-04
# Number of trials: 9/10 (1 PENDING, 4 RUNNING, 4 TERMINATED)
# +-------------------------+------------+------------------+---------+--------+--------+--------------+---------------+---------------+---------------+--------+---------+----------------------+
# | Trial name              | status     | loc              | act1    | act2   | act3   |   batch_size |   hidden_dim1 |   hidden_dim2 |   hidden_dim3 |     lr |    loss |   training_iteration |
# |-------------------------+------------+------------------+---------+--------+--------+--------------+---------------+---------------+---------------+--------+---------+----------------------|
# | trainable_func_8f3f3e50 | RUNNING    | 172.28.0.2:31180 | relu    | selu   | selu   |           16 |           180 |           120 |           150 | 0.0006 | 2.28767 |                    6 |
# | trainable_func_97d7cd20 | RUNNING    | 172.28.0.2:31172 | selu    | tanh   | relu   |           16 |            90 |           170 |            90 | 0.0008 |         |                      |
# | trainable_func_9be5e410 | RUNNING    | 172.28.0.2:31125 | tanh    | relu   | selu   |           32 |            60 |            60 |           170 | 0.0006 |         |                      |
# | trainable_func_9c00de64 | RUNNING    | 172.28.0.2:31280 | selu    | tanh   | selu   |           16 |           140 |           160 |            80 | 0.0007 |         |                      |
# | trainable_func_9c4c386e | PENDING    |                  | relu    | selu   | tanh   |           16 |           110 |           170 |            90 | 0.001  |         |                      |
# | trainable_func_8ca59aa4 | TERMINATED | 172.28.0.2:31125 | relu    | selu   | tanh   |           16 |            50 |            50 |           180 | 0.0006 | 1.89081 |                   12 |
# | trainable_func_8f252006 | TERMINATED | 172.28.0.2:31172 | tanh    | selu   | selu   |           32 |           120 |           140 |           180 | 0.0008 | 1.07167 |                   12 |
# | trainable_func_8f2acb96 | TERMINATED | 172.28.0.2:31180 | relu    | tanh   | tanh   |           32 |           130 |           190 |           180 | 0.0005 | 5.70066 |                    4 |
# | trainable_func_8f3539fa | TERMINATED | 172.28.0.2:31280 | relu    | tanh   | selu   |           32 |           180 |           170 |            80 | 0.001  | 1.34428 |                   12 |
# +-------------------------+------------+------------------+---------+--------+--------+--------------+---------------+---------------+---------------+--------+---------+----------------------+
#
#
# Result for trainable_func_9be5e410:
#   date: 2022-07-27_08-46-30
#   done: false
#   epoch: 0
#   experiment_id: c46bbe75ad6e48d8a005acfd916fbc35
#   hostname: f5eee09c4874
#   iterations_since_restore: 1
#   loss: 35.309302517165776
#   node_ip: 172.28.0.2
#   pid: 31125
#   should_checkpoint: true
#   time_since_restore: 0.7595231533050537
#   time_this_iter_s: 0.7595231533050537
#   time_total_s: 0.7595231533050537
#   timestamp: 1658911590
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: 9be5e410
#   warmup_time: 0.0051500797271728516
#
# Result for trainable_func_97d7cd20:
#   date: 2022-07-27_08-46-31
#   done: false
#   epoch: 0
#   experiment_id: c88e6a21a2f049109768804a8199d57f
#   hostname: f5eee09c4874
#   iterations_since_restore: 1
#   loss: 21.512985569481128
#   node_ip: 172.28.0.2
#   pid: 31172
#   should_checkpoint: true
#   time_since_restore: 1.2388217449188232
#   time_this_iter_s: 1.2388217449188232
#   time_total_s: 1.2388217449188232
#   timestamp: 1658911591
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: 97d7cd20
#   warmup_time: 0.005120754241943359
#
# Result for trainable_func_9c00de64:
#   date: 2022-07-27_08-46-31
#   done: false
#   epoch: 0
#   experiment_id: a1a929bb1f0e4ac0baf539434a720b93
#   hostname: f5eee09c4874
#   iterations_since_restore: 1
#   loss: 8.049292942905403
#   node_ip: 172.28.0.2
#   pid: 31280
#   should_checkpoint: true
#   time_since_restore: 1.2020211219787598
#   time_this_iter_s: 1.2020211219787598
#   time_total_s: 1.2020211219787598
#   timestamp: 1658911591
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: 9c00de64
#   warmup_time: 0.015590429306030273
#
# Result for trainable_func_9be5e410:
#   date: 2022-07-27_08-46-33
#   done: true
#   epoch: 3
#   experiment_id: c46bbe75ad6e48d8a005acfd916fbc35
#   hostname: f5eee09c4874
#   iterations_since_restore: 4
#   loss: 12.17702726607116
#   node_ip: 172.28.0.2
#   pid: 31125
#   should_checkpoint: true
#   time_since_restore: 2.928083896636963
#   time_this_iter_s: 0.6455411911010742
#   time_total_s: 2.928083896636963
#   timestamp: 1658911593
#   timesteps_since_restore: 0
#   training_iteration: 4
#   trial_id: 9be5e410
#   warmup_time: 0.0051500797271728516
#
# Result for trainable_func_8f3f3e50:
#   date: 2022-07-27_08-46-33
#   done: true
#   epoch: 7
#   experiment_id: 9851dc6b293d48f4936769b227e8e01c
#   hostname: f5eee09c4874
#   iterations_since_restore: 8
#   loss: 1.663043233491778
#   node_ip: 172.28.0.2
#   pid: 31180
#   should_checkpoint: true
#   time_since_restore: 10.27434778213501
#   time_this_iter_s: 1.2136971950531006
#   time_total_s: 10.27434778213501
#   timestamp: 1658911593
#   timesteps_since_restore: 0
#   training_iteration: 8
#   trial_id: 8f3f3e50
#   warmup_time: 0.01262521743774414
#
# Result for trainable_func_9c4c386e:
#   date: 2022-07-27_08-46-34
#   done: false
#   epoch: 0
#   experiment_id: c46bbe75ad6e48d8a005acfd916fbc35
#   hostname: f5eee09c4874
#   iterations_since_restore: 1
#   loss: 6.366628465155992
#   node_ip: 172.28.0.2
#   pid: 31125
#   should_checkpoint: true
#   time_since_restore: 1.1373140811920166
#   time_this_iter_s: 1.1373140811920166
#   time_total_s: 1.1373140811920166
#   timestamp: 1658911594
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: 9c4c386e
#   warmup_time: 0.0051500797271728516
#
# Result for trainable_func_9dc6351e:
#   date: 2022-07-27_08-46-34
#   done: false
#   epoch: 0
#   experiment_id: 9851dc6b293d48f4936769b227e8e01c
#   hostname: f5eee09c4874
#   iterations_since_restore: 1
#   loss: 33.58691025306137
#   node_ip: 172.28.0.2
#   pid: 31180
#   should_checkpoint: true
#   time_since_restore: 0.8222024440765381
#   time_this_iter_s: 0.8222024440765381
#   time_total_s: 0.8222024440765381
#   timestamp: 1658911594
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: 9dc6351e
#   warmup_time: 0.01262521743774414
#
# == Status ==
# Current time: 2022-07-27 08:46:36 (running for 00:00:31.61)
# Memory usage on this node: 2.2/12.7 GiB
# Using AsyncHyperBand: num_stopped=3
# Bracket: Iter 8.000: -1.3988540027902818 | Iter 4.000: -3.470584311148012
# Bracket: Iter 8.000: -1.627794953731593
# Bracket:
# Bracket:
# Bracket:
# Resources requested: 2.0/2 CPUs, 0/0 GPUs, 0.0/7.36 GiB heap, 0.0/3.68 GiB objects
# Result logdir: /root/ray_results/trainable_func_2022-07-27_08-46-04
# Number of trials: 10/10 (4 RUNNING, 6 TERMINATED)
# +-------------------------+------------+------------------+---------+--------+--------+--------------+---------------+---------------+---------------+--------+----------+----------------------+
# | Trial name              | status     | loc              | act1    | act2   | act3   |   batch_size |   hidden_dim1 |   hidden_dim2 |   hidden_dim3 |     lr |     loss |   training_iteration |
# |-------------------------+------------+------------------+---------+--------+--------+--------------+---------------+---------------+---------------+--------+----------+----------------------|
# | trainable_func_97d7cd20 | RUNNING    | 172.28.0.2:31172 | selu    | tanh   | relu   |           16 |            90 |           170 |            90 | 0.0008 |  3.26472 |                    5 |
# | trainable_func_9c00de64 | RUNNING    | 172.28.0.2:31280 | selu    | tanh   | selu   |           16 |           140 |           160 |            80 | 0.0007 |  1.6938  |                    4 |
# | trainable_func_9c4c386e | RUNNING    | 172.28.0.2:31125 | relu    | selu   | tanh   |           16 |           110 |           170 |            90 | 0.001  |  2.47372 |                    2 |
# | trainable_func_9dc6351e | RUNNING    | 172.28.0.2:31180 | selu    | selu   | selu   |           32 |           180 |           100 |            80 | 0.001  |  3.78165 |                    3 |
# | trainable_func_8ca59aa4 | TERMINATED | 172.28.0.2:31125 | relu    | selu   | tanh   |           16 |            50 |            50 |           180 | 0.0006 |  1.89081 |                   12 |
# | trainable_func_8f252006 | TERMINATED | 172.28.0.2:31172 | tanh    | selu   | selu   |           32 |           120 |           140 |           180 | 0.0008 |  1.07167 |                   12 |
# | trainable_func_8f2acb96 | TERMINATED | 172.28.0.2:31180 | relu    | tanh   | tanh   |           32 |           130 |           190 |           180 | 0.0005 |  5.70066 |                    4 |
# | trainable_func_8f3539fa | TERMINATED | 172.28.0.2:31280 | relu    | tanh   | selu   |           32 |           180 |           170 |            80 | 0.001  |  1.34428 |                   12 |
# | trainable_func_8f3f3e50 | TERMINATED | 172.28.0.2:31180 | relu    | selu   | selu   |           16 |           180 |           120 |           150 | 0.0006 |  1.66304 |                    8 |
# | trainable_func_9be5e410 | TERMINATED | 172.28.0.2:31125 | tanh    | relu   | selu   |           32 |            60 |            60 |           170 | 0.0006 | 12.177   |                    4 |
# +-------------------------+------------+------------------+---------+--------+--------+--------------+---------------+---------------+---------------+--------+----------+----------------------+
#
#
# Result for trainable_func_97d7cd20:
#   date: 2022-07-27_08-46-36
#   done: false
#   epoch: 5
#   experiment_id: c88e6a21a2f049109768804a8199d57f
#   hostname: f5eee09c4874
#   iterations_since_restore: 6
#   loss: 2.9678034339414943
#   node_ip: 172.28.0.2
#   pid: 31172
#   should_checkpoint: true
#   time_since_restore: 6.4785637855529785
#   time_this_iter_s: 1.0930325984954834
#   time_total_s: 6.4785637855529785
#   timestamp: 1658911596
#   timesteps_since_restore: 0
#   training_iteration: 6
#   trial_id: 97d7cd20
#   warmup_time: 0.005120754241943359
#
# Result for trainable_func_9c00de64:
#   date: 2022-07-27_08-46-37
#   done: false
#   epoch: 5
#   experiment_id: a1a929bb1f0e4ac0baf539434a720b93
#   hostname: f5eee09c4874
#   iterations_since_restore: 6
#   loss: 0.987305468984389
#   node_ip: 172.28.0.2
#   pid: 31280
#   should_checkpoint: true
#   time_since_restore: 7.160644054412842
#   time_this_iter_s: 1.1147942543029785
#   time_total_s: 7.160644054412842
#   timestamp: 1658911597
#   timesteps_since_restore: 0
#   training_iteration: 6
#   trial_id: 9c00de64
#   warmup_time: 0.015590429306030273
#
# Result for trainable_func_9dc6351e:
#   date: 2022-07-27_08-46-39
#   done: true
#   epoch: 7
#   experiment_id: 9851dc6b293d48f4936769b227e8e01c
#   hostname: f5eee09c4874
#   iterations_since_restore: 8
#   loss: 1.4508613623822553
#   node_ip: 172.28.0.2
#   pid: 31180
#   should_checkpoint: true
#   time_since_restore: 6.385077238082886
#   time_this_iter_s: 0.7274456024169922
#   time_total_s: 6.385077238082886
#   timestamp: 1658911599
#   timesteps_since_restore: 0
#   training_iteration: 8
#   trial_id: 9dc6351e
#   warmup_time: 0.01262521743774414
#
# Result for trainable_func_9c4c386e:
#   date: 2022-07-27_08-46-40
#   done: false
#   epoch: 5
#   experiment_id: c46bbe75ad6e48d8a005acfd916fbc35
#   hostname: f5eee09c4874
#   iterations_since_restore: 6
#   loss: 1.255257049268114
#   node_ip: 172.28.0.2
#   pid: 31125
#   should_checkpoint: true
#   time_since_restore: 6.973822116851807
#   time_this_iter_s: 1.1377770900726318
#   time_total_s: 6.973822116851807
#   timestamp: 1658911600
#   timesteps_since_restore: 0
#   training_iteration: 6
#   trial_id: 9c4c386e
#   warmup_time: 0.0051500797271728516
#
# == Status ==
# Current time: 2022-07-27 08:46:41 (running for 00:00:36.80)
# Memory usage on this node: 2.0/12.7 GiB
# Using AsyncHyperBand: num_stopped=4
# Bracket: Iter 8.000: -1.3539645347191636 | Iter 4.000: -2.9805610440665307
# Bracket: Iter 8.000: -1.627794953731593
# Bracket:
# Bracket:
# Bracket:
# Resources requested: 1.5/2 CPUs, 0/0 GPUs, 0.0/7.36 GiB heap, 0.0/3.68 GiB objects
# Result logdir: /root/ray_results/trainable_func_2022-07-27_08-46-04
# Number of trials: 10/10 (3 RUNNING, 7 TERMINATED)
# +-------------------------+------------+------------------+---------+--------+--------+--------------+---------------+---------------+---------------+--------+-----------+----------------------+
# | Trial name              | status     | loc              | act1    | act2   | act3   |   batch_size |   hidden_dim1 |   hidden_dim2 |   hidden_dim3 |     lr |      loss |   training_iteration |
# |-------------------------+------------+------------------+---------+--------+--------+--------------+---------------+---------------+---------------+--------+-----------+----------------------|
# | trainable_func_97d7cd20 | RUNNING    | 172.28.0.2:31172 | selu    | tanh   | relu   |           16 |            90 |           170 |            90 | 0.0008 |  2.44965  |                    9 |
# | trainable_func_9c00de64 | RUNNING    | 172.28.0.2:31280 | selu    | tanh   | selu   |           16 |           140 |           160 |            80 | 0.0007 |  0.974171 |                    8 |
# | trainable_func_9c4c386e | RUNNING    | 172.28.0.2:31125 | relu    | selu   | tanh   |           16 |           110 |           170 |            90 | 0.001  |  1.72024  |                    7 |
# | trainable_func_8ca59aa4 | TERMINATED | 172.28.0.2:31125 | relu    | selu   | tanh   |           16 |            50 |            50 |           180 | 0.0006 |  1.89081  |                   12 |
# | trainable_func_8f252006 | TERMINATED | 172.28.0.2:31172 | tanh    | selu   | selu   |           32 |           120 |           140 |           180 | 0.0008 |  1.07167  |                   12 |
# | trainable_func_8f2acb96 | TERMINATED | 172.28.0.2:31180 | relu    | tanh   | tanh   |           32 |           130 |           190 |           180 | 0.0005 |  5.70066  |                    4 |
# | trainable_func_8f3539fa | TERMINATED | 172.28.0.2:31280 | relu    | tanh   | selu   |           32 |           180 |           170 |            80 | 0.001  |  1.34428  |                   12 |
# | trainable_func_8f3f3e50 | TERMINATED | 172.28.0.2:31180 | relu    | selu   | selu   |           16 |           180 |           120 |           150 | 0.0006 |  1.66304  |                    8 |
# | trainable_func_9be5e410 | TERMINATED | 172.28.0.2:31125 | tanh    | relu   | selu   |           32 |            60 |            60 |           170 | 0.0006 | 12.177    |                    4 |
# | trainable_func_9dc6351e | TERMINATED | 172.28.0.2:31180 | selu    | selu   | selu   |           32 |           180 |           100 |            80 | 0.001  |  1.45086  |                    8 |
# +-------------------------+------------+------------------+---------+--------+--------+--------------+---------------+---------------+---------------+--------+-----------+----------------------+
#
#
# Result for trainable_func_97d7cd20:
#   date: 2022-07-27_08-46-42
#   done: false
#   epoch: 10
#   experiment_id: c88e6a21a2f049109768804a8199d57f
#   hostname: f5eee09c4874
#   iterations_since_restore: 11
#   loss: 2.1238921011775584
#   node_ip: 172.28.0.2
#   pid: 31172
#   should_checkpoint: true
#   time_since_restore: 12.038828134536743
#   time_this_iter_s: 0.9071569442749023
#   time_total_s: 12.038828134536743
#   timestamp: 1658911602
#   timesteps_since_restore: 0
#   training_iteration: 11
#   trial_id: 97d7cd20
#   warmup_time: 0.005120754241943359
#
# Result for trainable_func_97d7cd20:
#   date: 2022-07-27_08-46-43
#   done: true
#   epoch: 11
#   experiment_id: c88e6a21a2f049109768804a8199d57f
#   hostname: f5eee09c4874
#   iterations_since_restore: 12
#   loss: 2.1393322288858765
#   node_ip: 172.28.0.2
#   pid: 31172
#   should_checkpoint: true
#   time_since_restore: 13.001718044281006
#   time_this_iter_s: 0.9628899097442627
#   time_total_s: 13.001718044281006
#   timestamp: 1658911603
#   timesteps_since_restore: 0
#   training_iteration: 12
#   trial_id: 97d7cd20
#   warmup_time: 0.005120754241943359
#
# Result for trainable_func_9c00de64:
#   date: 2022-07-27_08-46-43
#   done: false
#   epoch: 10
#   experiment_id: a1a929bb1f0e4ac0baf539434a720b93
#   hostname: f5eee09c4874
#   iterations_since_restore: 11
#   loss: 1.1013283407206886
#   node_ip: 172.28.0.2
#   pid: 31280
#   should_checkpoint: true
#   time_since_restore: 12.545738458633423
#   time_this_iter_s: 0.8421225547790527
#   time_total_s: 12.545738458633423
#   timestamp: 1658911603
#   timesteps_since_restore: 0
#   training_iteration: 11
#   trial_id: 9c00de64
#   warmup_time: 0.015590429306030273
#
# Result for trainable_func_9c00de64:
#   date: 2022-07-27_08-46-44
#   done: true
#   epoch: 11
#   experiment_id: a1a929bb1f0e4ac0baf539434a720b93
#   hostname: f5eee09c4874
#   iterations_since_restore: 12
#   loss: 0.9201858834540543
#   node_ip: 172.28.0.2
#   pid: 31280
#   should_checkpoint: true
#   time_since_restore: 13.317214965820312
#   time_this_iter_s: 0.7714765071868896
#   time_total_s: 13.317214965820312
#   timestamp: 1658911604
#   timesteps_since_restore: 0
#   training_iteration: 12
#   trial_id: 9c00de64
#   warmup_time: 0.015590429306030273
# 2022-07-27 08:46:45,102	INFO tune.py:748 -- Total run time: 40.78 seconds (40.53 seconds for the tuning loop).
# Result for trainable_func_9c4c386e:
#   date: 2022-07-27_08-46-44
#   done: true
#   epoch: 11
#   experiment_id: c46bbe75ad6e48d8a005acfd916fbc35
#   hostname: f5eee09c4874
#   iterations_since_restore: 12
#   loss: 0.9008336415412723
#   node_ip: 172.28.0.2
#   pid: 31125
#   should_checkpoint: true
#   time_since_restore: 11.725605249404907
#   time_this_iter_s: 0.4023897647857666
#   time_total_s: 11.725605249404907
#   timestamp: 1658911604
#   timesteps_since_restore: 0
#   training_iteration: 12
#   trial_id: 9c4c386e
#   warmup_time: 0.0051500797271728516
#
# == Status ==
# Current time: 2022-07-27 08:46:44 (running for 00:00:40.58)
# Memory usage on this node: 1.5/12.7 GiB
# Using AsyncHyperBand: num_stopped=4
# Bracket: Iter 8.000: -1.3539645347191636 | Iter 4.000: -2.9805610440665307
# Bracket: Iter 8.000: -1.627794953731593
# Bracket:
# Bracket:
# Bracket:
# Resources requested: 0/2 CPUs, 0/0 GPUs, 0.0/7.36 GiB heap, 0.0/3.68 GiB objects
# Result logdir: /root/ray_results/trainable_func_2022-07-27_08-46-04
# Number of trials: 10/10 (10 TERMINATED)
# +-------------------------+------------+------------------+---------+--------+--------+--------------+---------------+---------------+---------------+--------+-----------+----------------------+
# | Trial name              | status     | loc              | act1    | act2   | act3   |   batch_size |   hidden_dim1 |   hidden_dim2 |   hidden_dim3 |     lr |      loss |   training_iteration |
# |-------------------------+------------+------------------+---------+--------+--------+--------------+---------------+---------------+---------------+--------+-----------+----------------------|
# | trainable_func_8ca59aa4 | TERMINATED | 172.28.0.2:31125 | relu    | selu   | tanh   |           16 |            50 |            50 |           180 | 0.0006 |  1.89081  |                   12 |
# | trainable_func_8f252006 | TERMINATED | 172.28.0.2:31172 | tanh    | selu   | selu   |           32 |           120 |           140 |           180 | 0.0008 |  1.07167  |                   12 |
# | trainable_func_8f2acb96 | TERMINATED | 172.28.0.2:31180 | relu    | tanh   | tanh   |           32 |           130 |           190 |           180 | 0.0005 |  5.70066  |                    4 |
# | trainable_func_8f3539fa | TERMINATED | 172.28.0.2:31280 | relu    | tanh   | selu   |           32 |           180 |           170 |            80 | 0.001  |  1.34428  |                   12 |
# | trainable_func_8f3f3e50 | TERMINATED | 172.28.0.2:31180 | relu    | selu   | selu   |           16 |           180 |           120 |           150 | 0.0006 |  1.66304  |                    8 |
# | trainable_func_97d7cd20 | TERMINATED | 172.28.0.2:31172 | selu    | tanh   | relu   |           16 |            90 |           170 |            90 | 0.0008 |  2.13933  |                   12 |
# | trainable_func_9be5e410 | TERMINATED | 172.28.0.2:31125 | tanh    | relu   | selu   |           32 |            60 |            60 |           170 | 0.0006 | 12.177    |                    4 |
# | trainable_func_9c00de64 | TERMINATED | 172.28.0.2:31280 | selu    | tanh   | selu   |           16 |           140 |           160 |            80 | 0.0007 |  0.920186 |                   12 |
# | trainable_func_9c4c386e | TERMINATED | 172.28.0.2:31125 | relu    | selu   | tanh   |           16 |           110 |           170 |            90 | 0.001  |  0.900834 |                   12 |
# | trainable_func_9dc6351e | TERMINATED | 172.28.0.2:31180 | selu    | selu   | selu   |           32 |           180 |           100 |            80 | 0.001  |  1.45086  |                    8 |
# +-------------------------+------------+------------------+---------+--------+--------+--------------+---------------+---------------+---------------+--------+-----------+----------------------+
#
#
# Best trial config: {'act1 ': 'relu', 'act2': 'selu', 'act3': 'tanh', 'lr': 0.001, 'batch_size': 16, 'hidden_dim1': 110.0, 'hidden_dim2': 170.0, 'hidden_dim3': 90.0}
# Best trial final validation score: 0.9008336415412723
# Best trial test set score: 1.8234688252106945

# %%
import random
random.seed(1)
Best_trial_config = {'act1 ': 'relu', 'act2': 'selu', 'act3': 'tanh', 'lr':0.001 , 'batch_size': 16, 'hidden_dim1': 130.0, 'hidden_dim2': 80.0, 'hidden_dim3': 200.0}
epochs = 12
config = {'act1 ': 'relu', 'act2': 'selu', 'act3': 'tanh', 'lr': 0.001, 'batch_size': 16, 'hidden_dim1': 130.0, 'hidden_dim2': 80.0, 'hidden_dim3': 200.0}
net = Net(Best_trial_config)
criterion = nn.MSELoss(reduction='sum')

    # # Define an optimizer 
optimizer = optim.Adam(net.parameters(), lr=config.get("lr",0.0003))

trainset, testset = load_data()

    # Split the dataset into training and validation sets
train_size = int(len(trainset) * 0.8)
train_subset, val_subset = random_split(trainset, [train_size, len(trainset) - train_size])

    # Define data loaders (which combines a dataset and a sampler, and provides an iterable over the given dataset)
trainloader = torch.utils.data.DataLoader(
    train_subset,
    batch_size=int(config.get("batch_size",32)),
    shuffle=True,
    num_workers=2)
valloader = torch.utils.data.DataLoader(
    val_subset,
    batch_size=int(config.get("batch_size",32)),
    shuffle=True,
    num_workers=2)

for epoch in range(epochs): # loop over the dataset multiple times
     epoch_train_loss = 0.0
        # epoch_steps = 0
     net.train() # Prepare model for training
     for i, data in enumerate(trainloader):
            # get the inputs; data is a list of [inputs, labels]
            inputs, labels = data
            inputs, labels = inputs.to(device), labels.to(device)

            # zero the parameter gradients
            optimizer.zero_grad()

            # forward + backward + optimize
            outputs = net(inputs)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()

            '''
            Compute train loss without scaling to print
            ''' 
            # outputs = torch.tensor(scaler_labels.inverse_transform(outputs.detach().cpu())).to(device)    
            # labels = torch.tensor(scaler_labels.inverse_transform(labels.cpu())).to(device)  
            # loss_train = criterion(outputs, labels) 
            # epoch_train_loss += loss_train.detach().item()
        # print("[%d] loss: %.3f" % (epoch + 1, epoch_train_loss / len(train_subset)))

        # Validation loss
     val_loss = 0.0
     net.eval() # Prepare model for evaluation
     for i, data in enumerate(valloader):
            with torch.no_grad():
                inputs, labels = data
                inputs, labels = inputs.to(device), labels.to(device)

                outputs = net(inputs)

                # Inverse transform of the labels' scaler
                outputs = torch.tensor(scaler_labels.inverse_transform(outputs.detach().cpu())).to(device)    
                labels = torch.tensor(scaler_labels.inverse_transform(labels.cpu())).to(device) 

                loss = criterion(outputs, labels)
                val_loss += loss.cpu().numpy()

        # with tune.checkpoint_dir(epoch) as checkpoint_dir:
        # path = os.path.join(checkpoint_dir, "checkpoint")
        # torch.save((net.state_dict(), optimizer.state_dict()), path)

        # tune.report(epoch = epoch, loss=(val_loss / len(val_subset)))
print("Finished Training")
device = "cpu"
# best_trained_model.to(device)
test_score_value = test_score(Best_trial_config, net, device)
print(test_score_value)
# Out:
# Finished Training
# 1.6722123946104466
